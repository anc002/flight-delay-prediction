# %%
import pandas as pd
import glob

# %%
# Load and combine all 12 monthly files
files = sorted(glob.glob("/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING *.csv"))
print(f"Found {len(files)} files: {files}")

df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

print(f"\nCombined shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"\nMonths present: {sorted(df['MONTH'].unique())}")
df.head()
# Out:
# Found 12 files: ['/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 1.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 10.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 11.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 12.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 2.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 3.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 4.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 5.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 6.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 7.csv', '/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/T_ONTIME_REPORTING 8.csv', '/Users/an
# ...

# %%
df.to_csv("/Users/anzarchowdhury/Desktop/spring_26/ds4420/project/data/flight_del_jan_to_dec_25.csv", index=False)
print("Saved.")
# Out:
# Saved.
